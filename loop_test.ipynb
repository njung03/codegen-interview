# %%
from loop import ImportLoopDetector

file_path = "/Users/noellejung/Loop-Labyrinth-Analysis"

detector = ImportLoopDetector(file_path)
detector.parse_python_files()
detector.output_loop_information()
detector.visualize_dependency_graph()
print(detector.detect_import_loops())
# print("Vertices:")
graph = detector.dependency_graph
# for node in graph.nodes:
#     print(node)

# Print out the edges
print("\nEdges:")
for edge in graph.edges:
    print(edge)
# Out:
# [['/Users/noellejung/Loop-Labyrinth-Analysis/controllers/product_controller.py', '/Users/noellejung/Loop-Labyrinth-Analysis/services/product_service.py', '/Users/noellejung/Loop-Labyrinth-Analysis/models/product.py'], ['/Users/noellejung/Loop-Labyrinth-Analysis/services/session_service.py', '/Users/noellejung/Loop-Labyrinth-Analysis/models/user.py', '/Users/noellejung/Loop-Labyrinth-Analysis/controllers/user_controller.py', '/Users/noellejung/Loop-Labyrinth-Analysis/services/user_service.py', '/Users/noellejung/Loop-Labyrinth-Analysis/utils/common.py'], ['/Users/noellejung/Loop-Labyrinth-Analysis/services/user_service.py', '/Users/noellejung/Loop-Labyrinth-Analysis/models/user.py', '/Users/noellejung/Loop-Labyrinth-Analysis/controllers/user_controller.py'], ['/Users/noellejung/Loop-Labyrinth-Analysis/services/user_service.py', '/Users/noellejung/Loop-Labyrinth-Analysis/services/auth_service.py', '/Users/noellejung/Loop-Labyrinth-Analysis/models/user.py', '/Users/noellejung/Loop-Labyr
# ...
